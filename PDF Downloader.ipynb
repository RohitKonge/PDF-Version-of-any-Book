# %% [markdown]
# # Libgen

# %%
import requests, bs4
import pandas as pd

author = "Salman Rushdie"
author = author.split()
to_search = "Midnight's Children"
pdf_title = to_search
to_search_online = to_search.replace(" ", "+")
link_to_search = f"https://libgen.is/search.php?req={to_search_online}&open=0&res=100&view=simple&phrase=1&column=title"


# -----------------------------------------------------------------------------------------


list_of_dataframes = pd.read_html(link_to_search)
table = list_of_dataframes[2]
# table
a = list(table.loc[0])

table.columns = a
table.drop(0 , axis = 0, inplace = True)
table.reset_index(inplace = True)
table = table[(table['Extension'] == 'pdf')]
# table
table.sort_values('Year', ascending = False, inplace = True)
table_2 = table[['Author(s)', 'Title']]
# table_2
index_number = 0


# # -----------------------------------------------------------------------------------------


def check_for_author(index_for_author):
    actual_author_name = table_2['Author(s)'][index_for_author] 
    result = False
    for i in author :
        if actual_author_name.find(i) > -1 :
            result = True
            break
    return result


# # -----------------------------------------------------------------------------------------

# # def check_for_title(index_for_title):
# #     actual_title_name = table_2['Title'][index_for_title] 
# #     result = True
# #     for i in actual_title_name.split() :
# #         if to_search.find(i) == -1 :
# #             result = False
# #             break
# #     return result

 
# # for i in table_2.index :
# #     if((check_for_title(i)) & (check_for_author(i))) :
# #         index_number = i
# #         break

# # index_number
 
# # -----------------------------------------------------------------------------------------


for i in table_2.index :
    if((table_2['Title'][i].find(to_search) == 0 ) & (check_for_author(i))) :
        index_number = i
        break


# # -----------------------------------------------------------------------------------------


# # my_dict = dict(table['Title'])
# # for i in my_dict :
# #     if(my_dict[i].find(to_search) == 0):
# #         index_number = i
# #         break


# # -----------------------------------------------------------------------------------------



result = requests.get(link_to_search)

soup = bs4.BeautifulSoup(result.text,"lxml")

a = soup.select(".c > tr > td > a")

c = []
for i in a :
    b = i.get('href')
    if(b.find("book") == 0):
        c.append(b.split("=")[1])

index_of_book_to_download = c

link_of_download_page = f"http://library.lol/main/{index_of_book_to_download[index_number]}"

result_2 = requests.get(link_of_download_page)

soup = bs4.BeautifulSoup(result_2.text,"lxml")

d = soup.select("#download > h2 > a")

download_link = d[0].get('href')
download_link

r = requests.get(download_link, stream = True)

with open(f"Downloads/{pdf_title}.pdf","wb") as pdf:
    for chunk in r.iter_content(chunk_size=10000):
  
         if chunk:
             pdf.write(chunk)
# Out:
# C:\Users\AbhishekKonge\AppData\Local\Temp\ipykernel_18108\2311742433.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table.sort_values('Year', ascending = False, inplace = True)

# %% [markdown]
# # PDF Drive

# %%
#For PDF DRIVE

#search_link = 'https://www.pdfdrive.com/{...................}-books.html'



import requests, bs4, webbrowser
import pandas as pd

author = "Ernest Hemingway"
author = author.split()
to_search = "The Sun Also Rises"
pdf_title = to_search
to_search_online = to_search.replace(" ", "-")
link_to_search = f"http://www.pdfdrive.com/{to_search_online}-books.html"



result = requests.get(link_to_search)

soup = bs4.BeautifulSoup(result.text,"lxml")

name_of_books       = soup.select(".ai-search > h2")
year_of_books       = soup.select(".file-info > .fi-year ")
downloads_of_books   = soup.select(".file-info > .fi-hit")
to_make_download_links = soup.select(".file-right > a ")



a = []
b = []

for x in name_of_books :
    a.append(x.getText())

for y in downloads_of_books : 
    b.append(int(y.getText().split(" ")[0].replace(',','')))
    

    
df_book  = pd.DataFrame(data = zip(a,b), columns = ['Book', 'Downloads'])

df_book.sort_values('Downloads', ascending= False, inplace = True)


index_of_book = 0

for x in df_book.index:
    if(df_book.loc[x]['Book'].find(to_search) == 0) :
        index_of_book = x
        break

raw_download_link = to_make_download_links[index_of_book].get('href')

download_link = raw_download_link[::-1].replace('e', 'd', 1)[::-1]
download_link

link_of_download_page = f"http://www.pdfdrive.com{download_link}"
# link_of_download_page


webbrowser.open(link_of_download_page)  # Go to example.com

# result_2 = requests.get(link_of_download_page)

# soup = bs4.BeautifulSoup(result_2.text,"lxml")


# d = soup.select(".dialog > .dialog-main > .dialog-left > .ebook-main")
# d
# download_link = ""

# for x in d:
#     print(x.get('href'))
# #     if (x.get('href').find("/download") == 0):
# #         download_link = x.get('href')
# #         print x.get('href')
# #         break
# # download_link
    
# download_link = d[0].get('href')

# r = requests.get("https://www.pdfdrive.com/download.pdf?id=156852032&h=11fba076a6384bbf99bc5765d63b64af&u=cache&ext=pdf", stream = True)


# with open(f"Downloads/{pdf_title}.pdf","wb") as pdf:
#     for chunk in r.iter_content(chunk_size=1000000):
  
#          if chunk:
#              pdf.write(chunk)
# https://www.pdfdrive.com/henry-huggins-d185567187.html
# Out:
# True

# %% [markdown]
# # ZLib

# %%
import requests, bs4
import pandas as pd

# author = "Morgan Housel"
# # author = author.split()
# to_search = "The Psychology of Money"
# pdf_title = to_search
# to_search_online = to_search.replace(" ", "%20") + "%20" + author.replace(" ", "%20")
# link_to_search = f"https://en.de1lib.org/s/{to_search_online}/?languages%5B0%5D=english&extensions%5B0%5D=pdf"
# author = author.split()

# link_to_search






# list_of_dataframes = pd.read_html(link_to_search)
# table = list_of_dataframes[2]
# # table
# a = list(table.loc[0])

# table.columns = a
# table.drop(0 , axis = 0, inplace = True)
# table.reset_index(inplace = True)
# table = table[(table['Extension'] == 'pdf')]
# # table
# table.sort_values('Year', ascending = False, inplace = True)
# table_2 = table[['Author(s)', 'Title']]
# # table_2
# index_number = 0

# def check_for_author(index_for_author):
#     actual_author_name = table_2['Author(s)'][index_for_author] 
#     result = False
#     for i in author :
#         if actual_author_name.find(i) > -1 :
#             result = True
#             break
#     return result

# for i in table_2.index :
#     if((table_2['Title'][i].find(to_search) == 0 ) & (check_for_author(i))) :
#         index_number = i
#         break

# my_dict = dict(table['Title'])
# for i in my_dict :
#     if(my_dict[i].find(to_search) == 0):
#         index_number = i
#         break

# result = requests.get(link_to_search)

# soup = bs4.BeautifulSoup(result.text,"lxml")

# a = soup.select(".c > tr > td > a")

# c = []
# for i in a :
#     b = i.get('href')
#     if(b.find("book") == 0):
#         c.append(b.split("=")[1])

# index_of_book_to_download = c
# link_of_download_page = f"http://library.lol/main/{index_of_book_to_download[index_number]}"

# result_2 = requests.get(link_of_download_page)

# soup = bs4.BeautifulSoup(result_2.text,"lxml")

# d = soup.select("#download > h2 > a")

# download_link = d[0].get('href')

# r = requests.get(download_link, stream = True)


# with open(f"Downloads/{pdf_title}.pdf","wb") as pdf:
#     for chunk in r.iter_content(chunk_size=1000000):
  
#          if chunk:
#              pdf.write(chunk)











result_2 = requests.get("https://b-ok.asia/book/882239/c4d172?dsource=mostpopular")

soup = bs4.BeautifulSoup(result_2.text,"lxml")

d = soup.select(".row")

urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
download_link = d[0].get('href')

download_link

# download_link = "https://b-ok.asia/dl/5214617/5c2517"

# r = requests.get(download_link, stream = True)


# pdf_title = "Some_Book_From_Zlib_22222"

# with open(f"Downloads/{pdf_title}.pdf","wb") as pdf:
#     for chunk in r.iter_content(chunk_size=1000000):
  
#          if chunk:
#              pdf.write(chunk)
# Out:
# /
# https://booksc.org/
# https://z-lib.org/
# https://z-lib.org/
# #
# https://singlelogin.app?from=b-ok.asia%252Fbook%252F882239%252Fc4d172%253Fdsource%253Dmostpopular
# https://singlelogin.app/registration.php
# /howtodonate.php
# #
# #
# /book-add.php
# /request.php
# /booklists
# /category-list
# /popular.php
# /recently.php
# /top-zlibrarians.php
# /blog/
# /
# https://covers.zlibcdn2.com/covers/books/ea/45/62/ea45628f0fff15f6d9d51c8076201780.jpg
# /author/Simon Sinek
# /category/117/Business--Economics-Responsibility-and-Business-Ethics
# /dl/882239/3ab2c7?dsource=mostpopular
# /dl/882239/3ab2c7?dsource=mostpopular&openInBrowser
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# ireader/882239
# javascript://
# https://rec2me.com
# /terms/?q=apple
# /terms/?q=it%27s
# /terms/?q=companies
# /terms/?q=don%27t
# /terms/?q=customers
# /terms/?q=employees
# /terms/?q=inspire
# /terms/?q=didn%27t
# /terms/?q=southwest
# /terms/?q=industry
# /terms/?q=that%27s
# /terms/?q=wal
# /terms/?q=inspired
# /terms/?q=leaders
# /terms/?q=walton
# /terms/?q=mart
# /terms/?q=apple%27s
# /terms/?q=organizations
# /terms/?q=loyalty
# /terms/?q=tangible
# /terms/?q=clarity
# /terms/?q=we%27re
# /terms/?q=doesn%27t
# /terms/?q=marketing
# /terms/?q=rational
# /terms/?q=benefits
# /terms/?q=beliefs
# /terms/?q=gates
# /terms/?q=loyal
# /terms/?q=airlines
# /terms/?q=can%27t
# /terms/?q=manipulations
# /terms/?q=i%27m
# /terms/?q=microsoft
# /terms/?q=wasn%27t
# /terms/?q=businesses
# /terms/?q=steve
# /terms/?q=sales
# /terms/?q=you%27re
# /terms/?q=innovation
# /terms/?q=airline
# /terms/?q=tivo
# /terms/?q=advertising
# /terms/?q=dell
# /terms/?q=industries
# /terms/?q=langley
# /terms/?q=kelleher
# /terms/?q=believes
# /terms/?q=bruder
# /terms/?q=wright+brothers
# /terms/?q=computers
# /terms/?q=discipline
# /terms/?q=competition
# /terms/?q=company%27s
# /terms/?q=megaphone
# /terms/?q=fits
# /terms/?q=bethune
# /terms/?q=he%27s
# /terms/?q=customer
# /terms/?q=sam+walton
# #
# #
# /book/882240/f15e85
# /book/882240/f15e85
# /s/?q=Goldmann+Verlag
# /author/Christopher Moore
# /book/882238/d93bc7
# /book/882238/d93bc7
# /s/?q=Ellipses+Marketing
# /author/Jean-Pierre Boulay
# /android
# mailto: support@bookmail.org
# /faq.php
# /blog/
# /android
# /privacy.php
# /dmca.php
# #
# //b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=en
# //ru.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ru
# //es.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=es
# //it.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=it
# //el.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=el
# //ar.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ar
# //id.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=id
# //ms.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ms
# //hi.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=hi
# //de.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=de
# //fr.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=fr
# //pt.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=pt
# //uk.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=uk
# //pl.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=pl
# //zh.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=zh
# //ja.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ja
# //vi.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=vi
# //az.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=az
# //hy.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=hy
# //th.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=th
# //tr.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=tr
# //ka.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ka
# //bn.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=bn
# //ps.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ps
# //te.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=te
# //ur.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ur
# //ko.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=ko
# //sr.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=sr
# //bg.b-ok.asia/book/882239/c4d172?dsource=mostpopular&switchLanguage=bg

# %% [markdown]
# # Mangareader to Email

# %%
import pdfkit

config = pdfkit.configuration(wkhtmltopdf=r"C:\Program Files\wkhtmltopdf\bin\wkhtmltopdf.exe")
                             
pdfkit.from_url('https://mangareader.to/read/one-piece-3/en/chapter-1033','mangaopenpiece-1033.pdf', configuration = config)
# Out:
# True
